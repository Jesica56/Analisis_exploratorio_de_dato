# %%
import operaciones

# %%
# !ls
# Out:
# operaciones.py	__pycache__  sample_data

# %%
import importlib
import operaciones
importlib.reload(operaciones)
# Out:
# <module 'operaciones' from '/content/operaciones.py'>

# %%
# !cat operaciones.py
# Out:
# def suma02(a,b):
#  return a + b
#
# def producto(a, b):
#  return a * b
#
# def potencia(a, b):
#  return a ** b
#
# def division(numerador, divisor):
#    if divisor != 0:
#        division = numerador / divisor
#        entera = numerador // divisor
#        resto = numerador % divisor
#        return f"División real: {division}, entera: {entera}, resto: {resto}"
#    else:
#        return "Error: No se puede dividir por cero"
#
# def raiz(numero, n):
#     if n == 0:
#         return "Error: no se puede calcular la raíz con exponente 0"
#     if numero < 0 and n % 2 == 0:
#         return "Error: no se puede calcular la raíz par de un número negativo"
#     else:
#         return numero ** (1/n)

# %%
import operaciones

# %%
print(operaciones.suma02(4, 6))
# Out:
# 10

# %%
print(operaciones.potencia(4, 2))
# Out:
# 16

# %%
print(operaciones.division(4, 6))
# Out:
# División real: 0.6666666666666666, entera: 0, resto: 4
